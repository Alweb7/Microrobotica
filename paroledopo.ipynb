# %%
import random
file = open("sei_personaggi_in_cerca_dautore_Luigi_Pirandello.txt", "r")#, encoding="uft-8")
righe=file.readlines()

                
file.close()

# %%
righe_senza_return = [riga[:-1] for riga in righe if len(riga) > 1]

# %%
libro = " ".join(righe_senza_return).lower()

# %%
punteggiatura = [",", ".", ":", ";", "(", ")", "?", "!", "-", "»"]
for carattere in punteggiatura:
    libro = libro.replace(carattere, " ")

# %%
parole = libro.split(" ")
parole = [parola for parola in parole if len(parola) > 0]

# %%
diz_successive = {}

# %%
for i in range(len(parole) - 1):
    parola_corrente = parole[i]
    parola_successiva = parole[i + 1]

    if parola_corrente in diz_successive:
        diz_successive[parola_corrente].append(parola_successiva)
    else:
        diz_successive[parola_corrente] = [parola_successiva]

# %%
diz_successive
# Out:
# {'sei': ['personaggi',
#   'personaggi',
#   'personaggi',
#   'un',
#   'cosã¬',
#   'curato',
#   'suo',
#   'personaggi',
#   'personaggi',
#   'vera',
#   'procurata'],
#  'personaggi': ['in',
#   'della',
#   'si',
#   'che',
#   'maschere',
#   'fantasticati',
#   'il',
#   'e',
#   'creati',
#   'signore',
#   'il',
#   'attraverseranno',
#   'il',
#   'spenti',
#   'e',
#   'il',
#   'siamo',
#   'qua',
#   'stanno',
#   'il',
#   'cosã¬',
#   'si',
#   'il',
#   'non',
#   'oltre',
#   'son',
#   'meno'],
#  'in': ['cerca',
#   'comunicazione',
#   'fondo',
#   'camiciotto',
#   'fondo',
#   'ginocchio',
#   'attesa',
#   'piedi',
#   'un',
#   'capo',
#   'bocca',
#   'camerino',
#   'tutto',
#   'ritardo',
#   'capo',
#   'gran',
#   'disparte',
#   'fondo',
#   'fondo',
#   'una',
#   'capo',
#   'piedi',
#   'iscena',
#   'un',
#   'tono',
#   'capo',
#   'modo',
#   'una',
#   'una',
#   'un',
#   "un'accigliata",
#   'mano',
#   'fondo',
#   'cerca',
#   'prova',
#   'attesa',
#   'tanti',
#   'tante',
#   'noi',
#   'fondo',
#   'applausi',
#   'loro',
#   'noi',
#   'noi',
#   'noi',
#   'una',
#   'applausi',
#   'un',
#   'disparte',
#   'braccio',
#   'questa',
#   'basso',
#   'nome',
#   'una',
#   'questi',
#   'testimonio',
#   'pace',
#   'piedi',
#   'mia',
#   'cui',
#   'me',
#   'pagamento',
#   'una',
#   'quel',
#   'te',
#   'atto',
#   'tutto',
#   'una',
#   'uno',
#   'campagna',
#   'un',
#   'tono',
#   'casa',
#   'pace',
#   'bisogno',
#   'lui',
#   'cerca',
#   'miseria',
#   'apparenza',
#   'faccia',
#   'noi',
#   'ogni',
#   'qualcuno',
#   "quell'atto",
#   "quell'atto",
#   'un',
#   'un',
#   'un',
#   'mezzo',
#   'modo',
#   'casa',
#   'loro',
#   'casa',
#   'casa',
#   'confidenza',
#   'ansia',
#   'me',
#   'tutti',
#   'azione',
#   'prima',
#   'libertã\xa0',
#   'fondo',
#   'magazzino',
#   'meglio',
#   'mezzo',
#   'lei',
#   'sã¨',
#   'sã¨',
#   'giro',
#   'mostra',
#   'mostra',
#   'fondo',
#   'fondo',
#   'una',
#   'serbo',
#   'nome',
#   'persona',
#   'un',
#   'teatro',
#   'una',
#   'attesa',
#   'un',
#   'mezzo',
#   'fondo',
#   'fretta',
#   "un'avventura",
#   'fretta',
#   'mostra',
#   'fondo',
#   'bello',
#   'quella',
#   'quel',
#   'vario',
#   'quel',
#   'una',
#   'attesa',
#   'un',
#   'rapporto',
#   'quel',
#   'un',
#   'una',
#   'pentola',
#   'alcuni',
#   'un',
#   'ogni',
#   'eterno',
#   'quel',
#   'alto',
#   'fila',
#   'piedi',
#   'mezzo',
#   'atto',
#   'casa',
#   'principio',
#   'tutti',
#   'camera',
#   'casa',
#   'trappola',
#   'genere',
#   'sordina',
#   'sã¨',
#   'riso',
#   "tant'altre",
#   'cui',
#   'quello',
#   "quell'ombra",
#   "quell'ombra",
#   'confidenza',
#   'casa',
#   "un'azione",
#   'cui',
#   'casa',
#   'quel',
#   'un',
#   'un',
#   'piedi',
#   'atteggiamento',
#   'una',
#   'testa',
#   'casa',
#   'te',
#   'modo',
#   'mezzo',
#   'iscena',
#   'una'],
#  'cerca': ["d'autore", "d'un", 'miseria'],
#  "d'autore": ['di'],
#  'di': ['luigi',
#   'scena',
#   'scena',
#   'giorno',
#   'teatro',
#   'prosa',
#   'giorno',
#   'scena',
#   'scena',
#   'scena',
#   'scena',
#   'scena',
#   'pirandello',
#   'scena',
#   'scena',
#   'scena',
#   'luce',
#   'scena',
#   'scena',
#   'scena',
#   'dieci',
#   'bianco',
#   'farsi',
#   'scena',
#   'scena',
#   'nuovo',
#   'scena',
#   'scena',
#   'leone',
#   'scena',
#   'scena',
#   'carta',
#   'libri',
#   'leone',
#   'lã\xa0',
#   'qua',
#   'socrate',
#   'scena',
#   'scena',
#   'legno',
#   'pirandello',
#   'maniera',
#   'non',
#   'nuovo',
#   'parti',
#   'se',
#   'tre',
#   'nuovo',
#   'questa',
#   'appositi',
#   'speciali',
#   'cera',
#   'stoffa',
#   'maniera',
#   'pelo',
#   'vergogna',
#   'nero',
#   'cera',
#   'diciotto',
#   'quattordici',
#   'nero',
#   'circa',
#   'bianco',
#   'seta',
#   'ventidue',
#   'scatto',
#   'lei',
#   'nuovo',
#   'furia',
#   'parer',
#   'fare',
#   'crearne',
#   'verosimili',
#   'farle',
#   'credere',
#   'uomini',
#   'quelli',
#   'non',
#   'lei',
#   'creazione',
#   'nero',
#   'una',
#   'questa',
#   'qua',
#   'scena',
#   'scena',
#   'fronte',
#   'nascere',
#   'straordinarie',
#   'compiere',
#   'trovare',
#   'questi',
#   'rappresentarlo',
#   'caricata',
#   'non',
#   'dave',
#   'danza',
#   'molto',
#   'quella',
#   'sprezzo',
#   'noi',
#   'noi',
#   'queste',
#   'ridurre',
#   'che',
#   'due',
#   'riconoscenza',
#   'dire',
#   'scatto',
#   'quel',
#   'due',
#   'cure',
#   'filosofia',
#   'tutti',
#   'danaro',
#   'danaro',
#   'mogano',
#   'madama',
#   'quelle',
#   'vendere',
#   'buona',
#   'tiranneggiarci',
#   'pagare',
#   'scatto',
#   'viverla',
#   'mogano',
#   'me',
#   'cose',
#   'cose',
#   'me',
#   'lei',
#   'farsi',
#   'no',
#   'cervello',
#   'fare',
#   'devozione',
#   'male',
#   'farlo',
#   'pensarlo',
#   'fare',
#   'esasperazione',
#   'quelle',
#   'umili',
#   'queste',
#   'nuovo',
#   'nuovo',
#   'tutto',
#   'me',
#   'bene',
#   'quel',
#   'spiegazione',
#   'lei',
#   'essa',
#   'crederla',
#   'sã¬',
#   'carta',
#   'firenze',
#   'roselline',
#   'maggio',
#   'rappresentar',
#   'parlare',
#   'lei',
#   'non',
#   'lontananza',
#   'dignitã\xa0',
#   'sã¨',
#   'ricomporre',
#   'tutti',
#   'dirle',
#   'farle',
#   'nascosto',
#   'cinico',
#   'scoprire',
#   'nascondere',
#   'tutte',
#   'tutta',
#   'certi',
#   'coccodrillo',
#   'sacrificarsi',
#   'notte',
#   'madama',
#   'sdegno',
#   'lei',
#   'fronte',
#   'noi',
#   'non',
#   'questa',
#   'quella',
#   'lui',
#   'me',
#   'veder',
#   'darlo',
#   'nuovo',
#   'me',
#   'lui',
#   'tutti',
#   'essere',
#   'molto',
#   'nuovo',
#   'straordinario',
#   'figurare',
#   'minuti',
#   'scena',
#   'prima',
#   'scena',
#   'scena',
#   'â«pelucheâ',
#   'madama',
#   'scena',
#   'mogano',
#   'scena',
#   'scena',
#   'scena',
#   'scena',
#   'scena',
#   'scena',
#   'carta',
#   'bene',
#   'scena',
#   'scena',
#   'carta',
#   'fissare',
#   'saper',
#   'per',
#   'me',
#   'lei',
#   'me',
#   'me',
#   'questo',
#   'noi',
#   'madama',
#   'scena',
#   'darmi',
#   'levarsi',
#   'pochi',
#   'lana',
#   'seta',
#   'piume',
#   'spavento',
#   'fuggire',
#   'dove',
#   'bussolotti',
#   'fatto',
#   'una',
#   'viver',
#   'loro',
#   'quella',
#   'un',
#   'no',
#   'scappar',
#   'nuovo',
#   'viverla',
#   'vederla',
#   'importanza',
#   'meglio',
#   'tutti',
#   'nuovo',
#   'nuovo',
#   'lui',
#   'sotto',
#   'compromettersi',
#   'sã¬',
#   'sotto',
#   'dolore',
#   'sdegno',
#   'quei',
#   'prima',
#   'madama',
#   'no',
#   'belli',
#   'mortificarsi',
#   'sorridere',
#   'leggerezza',
#   'spigliatezza',
#   'nero',
#   'nero',
#   'lei',
#   'una',
#   'sorpresa',
#   'meraviglia',
#   'sofferenza',
#   'ridere',
#   'spiare',
#   'sotto',
#   'nuovo',
#   'nuovo',
#   'sã¬',
#   'tra',
#   'loro',
#   'tutte',
#   'appena',
#   'lã\xa0',
#   'lui',
#   'sua',
#   'essere',
#   'una',
#   'raccoglimento',
#   'tutte',
#   'tanto',
#   'rappresentarlo',
#   'commozione',
#   'quietarsi',
#   'noi',
#   'meglio',
#   'non',
#   'tutto',
#   'lei',
#   'lei',
#   'strazio',
#   'scena',
#   'meditare',
#   'lui',
#   'quello',
#   'scatto',
#   'questo',
#   'placarmi',
#   'consigliarmi',
#   'nuovo',
#   'quel',
#   'scena',
#   'no',
#   'realtã\xa0',
#   'questa',
#   'qualche',
#   'ridere',
#   'fare',
#   'caratteri',
#   'tempo',
#   'palcoscenico',
#   'nuovo',
#   'questa',
#   'jeri',
#   'me',
#   'me',
#   'tutti',
#   'solito',
#   'metterlo',
#   'dargli',
#   'noi',
#   'mettersi',
#   'quel',
#   'noi',
#   'tutti',
#   'sã¨',
#   'tutti',
#   'fatti',
#   'lui',
#   'scena',
#   "un'orribile",
#   'cielo',
#   'cielo',
#   'atmosfera',
#   'sera',
#   'nascondersi',
#   'concretare',
#   'fargli',
#   'bocca',
#   'meglio',
#   'sfida',
#   'mostrare',
#   'proferire',
#   'queste',
#   'sgomento',
#   'figlio',
#   'mendico',
#   'tutti',
#   'quei',
#   'fronte',
#   'questa',
#   'lei',
#   'piã¹',
#   'noi',
#   'tutta',
#   'potergli',
#   'potergli',
#   'figlio',
#   'interporsi',
#   'separarli',
#   'tutti',
#   'portare',
#   'chi',
#   'lã\xa0',
#   'tutti',
#   'lui',
#   'rivoltella',
#   'farsi',
#   'esso',
#   'vivissima',
#   'dirlo',
#   'prima',
#   'lui',
#   'nuovo'],
#  'luigi': ['pirandello'],
#  'pirandello': ['i', 'â«il', 'che'],
#  'i': ['personaggi',
#   'lumi',
#   'piã¹',
#   'cani',
#   'tre',
#   'personaggi',
#   'â«personaggiâ',
#   'vivaci',
#   'primi',
#   'signori',
#   'personaggi',
#   'suoi',
#   'giovani',
#   'figli',
#   'sentimenti',
#   'ragazzi',
#   'sei',
#   'comici',
#   'campanelli',
#   'lumi',
#   'mobili',
#   'personaggi',
#   'personaggi',
#   'personaggi',
#   'personaggi',
#   'personaggi',
#   'personaggi',
#   'quali',
#   'mobili',
#   'servi',
#   'loro',
#   'cappellini',
#   'cappellini',
#   'vari',
#   'quali',
#   'nostri',
#   'suoi',
#   'capelli',
#   'suoi',
#   'suoi',
#   'macchinisti',
#   'personaggi',
#   'modi',
#   'cartellini',
#   'suoi',
#   'suoi',
#   'piedi',
#   'personaggi',
#   'cartellini',
#   'fiori',
#   'due',
#   'fiorellini',
#   'miei',
#   'suoi',
#   'piedi',
#   'tre'],
#  'della': ['commedia',
#   'compagnia',
#   'prova',
#   'compagnia',
#   'commedia',
#   'parte',
#   'sala',
#   'prima',
#   'tela',
#   'ragione',
#   'compagnia',
#   'commedia',
#   'fantasia',
#   'volubile',
#   'figura',
#   'â«mater',
#   'cittã\xa0',
#   'scaletta',
#   'fantasia',
#   'loro',
#   'morte',
#   'creazione',
#   'scena',
#   'terra',
#   'scena',
#   'nuova',
#   'gonna',
#   'scuola',
#   'vita',
#   'scuola',
#   'gonna',
#   'mia',
#   'donna',
#   'vergogna',
#   'vergogna',
#   'sua',
#   'sua',
#   'madre',
#   'mia',
#   'casa',
#   'tua',
#   'sala',
#   'saletta',
#   'sua',
#   'critica',
#   'signorina',
#   'signorina',
#   'scena',
#   'mamma',
#   'situazione',
#   'sua',
#   'scena',
#   'scena',
#   'mia',
#   'mia',
#   'tenda',
#   'loro',
#   'speciosa',
#   'realtã\xa0',
#   'loro',
#   'luce',
#   'presenza',
#   'vasca',
#   'nostra',
#   'tela'],
#  'commedia': ['da',
#   'non',
#   'di',
#   'e',
#   'bisogna',
#   'i',
#   'nuova',
#   'nuova',
#   'ã¨',
#   'se',
#   'che',
#   'e',
#   'sul',
#   'farai',
#   'lei'],
#  'da': ['fare',
#   'principio',
#   'parte',
#   'un',
#   'un',
#   'un',
#   'pranzo',
#   'studio',
#   'tavola',
#   'letto',
#   'questa',
#   'cuoco',
#   'cuoco',
#   'cuoco',
#   'cuoco',
#   'rappresentare',
#   'un',
#   'un',
#   'perdere',
#   'pazzi',
#   'rappresentare',
#   'perdere',
#   'strumento',
#   'questa',
#   'uno',
#   'un',
#   'fare',
#   'lei',
#   'appena',
#   'francis',
#   'un',
#   'quello',
#   'due',
#   'spettatore',
#   'lei',
#   'lei',
#   'un',
#   "quell'involto",
#   'quel',
#   'un',
#   'poter',
#   'poter',
#   'sarta',
#   'quella',
#   'quella',
#   'lei',
#   'rappresentare',
#   'me',
#   'quello',
#   'questo',
#   'padrona',
#   'dire',
#   'quella',
#   'un',
#   'parte',
#   'cavarne',
#   'sã¨',
#   'autore',
#   'questa',
#   'improvvisare',
#   'sã¨',
#   'ridere',
#   'la',
#   'chi',
#   'me',
#   'lettere',
#   'lettere',
#   'lettere',
#   'un',
#   'fuori',
#   'me',
#   'imparare',
#   'parte',
#   'due',
#   'madama',
#   'prima',
#   'un',
#   'me',
#   'lui',
#   'giardino',
#   'una',
#   'svolgere',
#   'creare',
#   'creare',
#   'questo',
#   'principio',
#   'tutti',
#   'far',
#   'fare',
#   'principio',
#   'un',
#   'cui',
#   'lei',
#   'fuori',
#   'pazzo',
#   'capo',
#   'piedi',
#   'cielo',
#   'una',
#   'destra',
#   'sinistra',
#   'destra',
#   'sinistra',
#   'un',
#   'sinistra'],
#  'fare': ['il',
#   'a',
#   'il',
#   'al',
#   'a',
#   'il',
#   'ho',
#   'a',
#   'a',
#   "l'attor",
#   'improvvisare',
#   'il',
#   'nojaltri',
#   'offesa',
#   'coi',
#   'con',
#   'lei',
#   'a',
#   'intendere',
#   'una',
#   'a',
#   'a',
#   'qua',
#   'quel',
#   'la',
#   'noi',
#   'una',
#   'una',
#   'adesso'],
#  'il': ['padre',
#   'figlio',
#   'giovinetto',
#   'direttore',
#   'primo',
#   'direttore',
#   'suggeritore',
#   'trovarobe',
#   'macchinista',
#   'segretario',
#   'sipario',
#   'direttore',
#   'capo',
#   'palcoscenico',
#   'macchinista',
#   'sipario',
#   'sipario',
#   'palcoscenico',
#   'palcoscenico',
#   'cupolino',
#   'pubblico',
#   'direttore',
#   'macchinista',
#   'direttore',
#   'direttore',
#   'macchinista',
#   'direttore',
#   'direttore',
#   'macchinista',
#   'mio',
#   'direttore',
#   'macchinista',
#   'direttore',
#   'secondo',
#   'macchinista',
#   'direttore',
#   'buon',
#   'suggeritore',
#   'copione',
#   'braccio',
#   'direttore',
#   'signor',
#   'suono',
#   'direttore',
#   'quale',
#   'bastone',
#   'braccio',
#   'corridojo',
#   'segretario',
#   'capocomico',
#   'segretario',
#   'capocomico',
#   'copione',
#   'direttore',
#   'palcoscenico',
#   'lato',
#   'suggeritore',
#   'copione',
#   'capocomico',
#   'direttore',
#   'capocomico',
#   'piacere',
#   'corridojo',
#   'capocomico',
#   'direttore',
#   'cagnolino',
#   'capocomico',
#   'cagnolino',
#   'secondo',
#   'davanti',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'suggeritore',
#   'capocomico',
#   'direttore',
#   'suggeritore',
#   'capocomico',
#   'direttore',
#   'suggeritore',
#   'capocomico',
#   'suggeritore',
#   'primo',
#   'berretto',
#   'capocomico',
#   'copione',
#   'primo',
#   'capocomico',
#   'primo',
#   'berretto',
#   'guscio',
#   'guscio',
#   'pieno',
#   'fantoccio',
#   'primo',
#   'capocomico',
#   'suggeritore',
#   'capocomico',
#   'corridojo',
#   'mezzo',
#   'sudore',
#   'senso',
#   'â«rimorsoâ',
#   'padre',
#   'figlio',
#   'â«doloreâ',
#   'vestiario',
#   'padre',
#   'velo',
#   'figlio',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'giovinetto',
#   'figlio',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'piacere',
#   'padre',
#   'capocomico',
#   'padre',
#   'contrario',
#   'capocomico',
#   'nostro',
#   'padre',
#   'capocomico',
#   'loro',
#   'padre',
#   'direttore',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'giovinetto',
#   'figlio',
#   'capocomico',
#   'direttore',
#   'padre',
#   'capocomico',
#   'primo',
#   'padre',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'copione',
#   'padre',
#   'dramma',
#   'padre',
#   'padre',
#   'â«prends',
#   'capocomico',
#   'padre',
#   'padre',
#   'giovinetto',
#   'volo',
#   'volo',
#   'volo',
#   'padre',
#   'figlio',
#   'figlio',
#   'giovinetto',
#   'padre',
#   'capocomico',
#   'padre',
#   'velo',
#   'padre',
#   'padre',
#   'velo',
#   'suo',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'loro',
#   'padre',
#   'suo',
#   'lutto',
#   'padre',
#   'suo',
#   'suo',
#   'coraggio',
#   'figlio',
#   'padre',
#   'marito',
#   'padre',
#   'primo',
#   'capocomico',
#   'figlio',
#   'padre',
#   'figlio',
#   'padre',
#   'conforto',
#   'rimorso',
#   'padre',
#   'rimorso',
#   'figlio',
#   'figlio',
#   'diritto',
#   'divano',
#   'padre',
#   'capocomico',
#   'padre',
#   'padre',
#   'capocomico',
#   'padre',
#   'male',
#   'senso',
#   'valore',
#   'padre',
#   'padre',
#   'padre',
#   'male',
#   'primo',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'male',
#   'padre',
#   'loro',
#   'mio',
#   'capocomico',
#   'padre',
#   'padre',
#   'figlio',
#   'figlio',
#   'padre',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'fastidio',
#   'padre',
#   'padre',
#   'minimo',
#   'padre',
#   'padre',
#   'mio',
#   'figlio',
#   'pensiero',
#   'vuoto',
#   'capocomico',
#   'figlio',
#   'padre',
#   'capocomico',
#   'padre',
#   'padre',
#   'dramma',
#   'padre',
#   'padre',
#   'tuo',
#   'padre',
#   'mio',
#   'dramma',
#   'ricordo',
#   'coraggio',
#   'padre',
#   'rosso',
#   'segno',
#   'segno',
#   'bisogno',
#   'rosso',
#   'pudore',
#   'capocomico',
#   'padre',
#   'capo',
#   'sospetto',
#   'lavoro',
#   'capocomico',
#   'padre',
#   'padre',
#   'padre',
#   'padre',
#   'dramma',
#   'dramma',
#   'figlio',
#   'figlio',
#   'padre',
#   'figlio',
#   'male',
#   'figlio',
#   'marciapiedi',
#   'regno',
#   'figlio',
#   'padre',
#   'padre',
#   'figlio',
#   'padre',
#   'figlio',
#   'padre',
#   'padre',
#   'pernio',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'suo',
#   'capocomico',
#   'padre',
#   'nostro',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'palcoscenico',
#   'primo',
#   'terzo',
#   'primo',
#   'teatro',
#   'terzo',
#   'palcoscenico',
#   'sipario',
#   'direttore',
#   'macchinista',
#   'suggeritore',
#   'trovarobe',
#   'direttore',
#   'capocomico',
#   'macchinista',
#   'capocomico',
#   'macchinista',
#   'capocomico',
#   'capocomico',
#   'trovarobe',
#   'trovarobe',
#   'capocomico',
#   'capocomico',
#   'tavolino',
#   'tavolino',
#   'direttore',
#   'capocomico',
#   'padre',
#   'paravento',
#   'direttore',
#   'capocomico',
#   'capocomico',
#   'direttore',
#   'direttore',
#   'capocomico',
#   'capocomico',
#   'suggeritore',
#   'capocomico',
#   'suggeritore',
#   'capocomico',
#   'servo',
#   'capocomico',
#   'capocomico',
#   'primo',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'primo',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'nome',
#   'padre',
#   'capocomico',
#   'tono',
#   'nome',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'merito',
#   'padre',
#   'capocomico',
#   'padre',
#   'gesto',
#   'capocomico',
#   'padre',
#   'nostro',
#   'primo',
#   'padre',
#   'signore',
#   'primo',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'trovarobe',
#   'capocomico',
#   'padre',
#   'trovarobe',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'mantello',
#   'mantello',
#   'mantello',
#   'padre',
#   'mantello',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'corridojo',
#   'padre',
#   'capocomico',
#   'primo',
#   'primo',
#   'padre',
#   'capocomico',
#   'mento',
#   'capo',
#   'capocomico',
#   'primo',
#   'padre',
#   'capocomico',
#   'pubblico',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'lavoro',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'padre',
#   'viso',
#   'padre',
#   'ribrezzo',
#   'volto',
#   'padre',
#   'cappellino',
#   'capocomico',
#   'padre',
#   'padre',
#   'padre',
#   'capocomico',
#   'meglio',
#   'capocomico',
#   'primo',
#   'primo',
#   'capocomico',
#   'cappello',
#   'suo',
#   'capocomico',
#   'capocomico',
#   'primo',
#   'padre',
#   'primo',
#   'padre',
#   'primo',
#   'capocomico',
#   'padre',
#   'tono',
#   'capocomico',
#   'primo',
#   'capocomico',
#   'primo',
#   'primo',
#   'gesto',
#   'timore',
#   'padre',
#   'capocomico',
#   'primo',
#   'capocomico',
#   'capocomico',
#   'modo',
#   'primo',
#   'capocomico',
#   'cenno',
#   'capo',
#   'capo',
#   'capocomico',
#   'capocomico',
#   'primo',
#   'primo',
#   'primo',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'signore',
#   'primo',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'bello',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'teatro',
#   'capocomico',
#   'piacere',
#   'capocomico',
#   'mio',
#   'busto',
#   'capocomico',
#   'capocomico',
#   'suo',
#   'capocomico',
#   'mio',
#   'mio',
#   'capocomico',
#   'suo',
#   'suo',
#   'padre',
#   'difficile',
#   'capo',
#   'capocomico',
#   'responsabile',
#   'capocomico',
#   'peso',
#   'dramma',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'mio',
#   'padre',
#   'momento',
#   'capocomico',
#   'nucleo',
#   'primo',
#   'padre',
#   'grido',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'macchinista',
#   'sipario',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'sipario',
#   'sipario',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'figlio',
#   'capocomico',
#   'dispetto',
#   'capo',
#   'bene',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'figlio',
#   'capocomico',
#   'primo',
#   'capocomico',
#   'pubblico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'primo',
#   'capocomico',
#   'padre',
#   'padre',
#   'giuoco',
#   'signore',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'primo',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'direttore',
#   'capocomico',
#   'padre',
#   'terreno',
#   'terreno',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'padre',
#   'travaglio',
#   'capocomico',
#   'padre',
#   'padre',
#   'padre',
#   'pubblico',
#   'capocomico',
#   'padre',
#   'capocomico',
#   'suo',
#   'capocomico',
#   'capocomico',
#   'capo',
#   'capocomico',
#   'capocomico',
#   'giardino',
#   'giardino',
#   'macchinista',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'capocomico',
#   'giovinetto',
#   'ragazzo',
#   'capo',
#   'capo',
#   'giovinetto',
#   'figlio',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'capocomico',
#   'padre',
#   'figlio',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'volo',
#   'figlio',
#   'padre',
#   'figlio',
#   'padre',
#   'giardino',
#   'guajo',
#   'giovinetto',
#   'padre',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'figlio',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'padre',
#   'capocomico',
#   'figlio',
#   'capocomico',
#   'cuore',
#   'figlio',
#   'capocomico',
#   'modo',
#   'padre',
#   'figlio',
#   'padre',
#   'petto',
#   'figlio',
#   'padre',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'padre',
#   'capocomico',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'capocomico',
#   'figlio',
#   'giardino',
#   'capocomico',
#   'giardino',
#   'figlio',
#   'volto',
#   'capocomico',
#   'figlio',
#   'padre',
#   'capocomico',
#   'figlio',
#   'ragazzo',
#   'ragazzo',
#   'giovinetto',
#   'capocomico',
#   'giovinetto',
#   'capocomico',
#   'padre',
#   'fondalino',
#   'primo',
#   'padre',
#   'fondalino',
#   'capocomico',
#   'palcoscenico',
#   'capocomico',
#   'teatro',
#   'fondalino',
#   'giovinetto',
#   'capocomico',
#   'riflettore',
#   'fondalino',
#   'notturno',
#   'figlio',
#   'padre',
#   'corridojo'],
#  'padre': ['la',
#   'la',
#   'sarã\xa0',
#   'e',
#   'facendosi',
#   "d'uno",
#   'seguendo',
#   'no',
#   'ferito',
#   'dico',
#   'eh',
#   'interrompendo',
#   'no',
#   'niente',
#   'appunto',
#   'ferito',
#   'al',
#   'risoluto',
#   'scartandola',
#   'vogliamo',
#   'no',
#   'guardino',
#   'e',
#   'ãˆ',
#   'e',
#   'con',
#   'con',
#   'no',
#   'con',
#   'accorrendo',
#   'le',
#   'la',
#   'lasciati',
#   'questa',
#   'subito',
#   'ferito',
#   'ma',
#   'la',
#   'finchã©',
#   'ho',
#   'ãˆ',
#   'tu',
#   'frasi',
#   'il',
#   'ma',
#   'sfido',
#   'ma',
#   'ma',
#   'ecco',
#   'ma',
#   'se',
#   'ma',
#   'ecco',
#   'non',
#   'benissimo',
#   'subito',
#   'ma',
#   'subito',
#   'io',
#   'ben',
#   'sissignore',
#   'questo',
#   'infame',
#   'ma',
#   "d'accordo",
#   'il',
#   'il',
#   'subito',
#   'appunto',
#   'e',
#   'tutti',
#   'ecco',
#   'lui',
#   'col',
#   'gridando',
#   'il',
#   'come',
#   'a',
#   'chi',
#   'ma',
#   'ma',
#   'ammesso',
#   'subito',
#   'umile',
#   'oh',
#   'scacciandola',
#   'eh',
#   'capirã\xa0',
#   'no',
#   'ma',
#   'ma',
#   'sã¬',
#   'e',
#   'come',
#   'no',
#   'ma',
#   'vediamo',
#   'ma',
#   'una',
#   'come',
#   'ma',
#   'appunto',
#   'eh',
#   'bisognerã\xa0',
#   'amalia',
#   'e',
#   'giã\xa0',
#   'come',
#   'non',
#   'giã\xa0',
#   'ho',
#   'umile',
#   'eh',
#   "m'ha",
#   'sissignore',
#   'il',
#   'da',
#   'non',
#   'ma',
#   'ecco',
#   'oh',
#   'per',
#   'ecco',
#   'ecco',
#   'raggiante',
#   'dominando',
#   'sarã\xa0',
#   "all'attenzione",
#   'che',
#   'no',
#   'accorrendo',
#   'anche',
#   'e',
#   'che',
#   'eseguirã\xa0',
#   'avanzando',
#   'la',
#   "c'ã¨",
#   'resterã\xa0',
#   'eh',
#   'dice',
#   'a',
#   'e',
#   'soltanto',
#   'non',
#   'subito',
#   'avanzandosi',
#   'di',
#   'correggendo',
#   'cercando',
#   'sissignore',
#   'io',
#   'appunto',
#   'una',
#   'sã¬',
#   'e',
#   'bisogna',
#   'quello',
#   'solenne',
#   'ecco',
#   'e',
#   'e',
#   'accorrendo',
#   'il',
#   'sollevando',
#   '*',
#   'a',
#   'con',
#   'ma',
#   'comprendo',
#   'non',
#   'ora',
#   'dopo',
#   'e',
#   'hanno',
#   'no',
#   'con',
#   'quasi',
#   'oh',
#   'con',
#   'credevo',
#   'se',
#   'con',
#   'non',
#   'e',
#   'e',
#   'giã\xa0',
#   'diceva',
#   'deve',
#   'e',
#   'al',
#   'ti',
#   'e',
#   'questo',
#   'appressandosi',
#   'afferrandolo',
#   'senza',
#   'lui',
#   'a',
#   'rimasto',
#   'levandosi',
#   'si'],
#  'la': ['madre',
#   'figliastra',
#   'bambina',
#   'prima',
#   'seconda',
#   'commedia',
#   'rappresentazione',
#   'sala',
#   'prova',
#   'prova',
#   'scena',
#   'prova',
#   'danza',
#   'sala',
#   'posta',
#   'posta',
#   'lampadina',
#   'prima',
#   'segni',
#   'reprensione',
#   'voce',
#   'prima',
#   'prima',
#   'prova',
#   'prima',
#   'prima',
#   'prima',
#   'sala',
#   'rossa',
#   'comune',
#   'comune',
#   'cucina',
#   'parte',
#   'bussola',
#   'didascalia',
#   'vuota',
#   'ragione',
#   'sua',
#   'fine',
#   'disposizione',
#   'bocca',
#   'â«vendettaâ',
#   'figliastra',
#   'madre',
#   'madre',
#   'figliastra',
#   'sorellina',
#   'madre',
#   'prova',
#   'figliastra',
#   'scaletta',
#   'loro',
#   'figliastra',
#   'madre',
#   'bambina',
#   'figliastra',
#   'sua',
#   'vita',
#   'prego',
#   'professione',
#   'natura',
#   'sua',
#   'mano',
#   'condurrã\xa0',
#   'bambina',
#   'madre',
#   'figliastra',
#   'buca',
#   'figliastra',
#   'ventura',
#   'creatura',
#   'ventura',
#   'prima',
#   'figliastra',
#   'commedia',
#   'concerteremo',
#   'passione',
#   'figliastra',
#   'passione',
#   'passione',
#   'figliastra',
#   'prima',
#   'figliastra',
#   'bambina',
#   'madre',
#   'porterã\xa0',
#   'prenderã\xa0',
#   'bacerã\xa0',
#   'rimetterã\xa0',
#   'toglierã\xa0',
#   'piã¹',
#   'madre',
#   'madre',
#   'vuol',
#   'considera',
#   'voce',
#   'madre',
#   'supplico',
#   'madre',
#   'faccia',
#   'guardi',
#   'guardi',
#   'madre',
#   'madre',
#   'supplico',
#   'sua',
#   'madre',
#   'figliastra',
#   'guardi',
#   'madre',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'noncuranza',
#   'costrinse',
#   'madre',
#   'figlia',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'madre',
#   'sua',
#   'prima',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'scusa',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'mia',
#   'camera',
#   'vetrina',
#   'specchiera',
#   'finestra',
#   'busta',
#   'vedo',
#   'figliastra',
#   'figliastra',
#   'mia',
#   'mia',
#   'madre',
#   'piã¹',
#   'madre',
#   'sente',
#   'madre',
#   'tua',
#   'sua',
#   'figliastra',
#   'sua',
#   'prima',
#   'figliastra',
#   'prima',
#   'prova',
#   'prima',
#   'intendeva',
#   'madre',
#   'figliastra',
#   'madre',
#   'madre',
#   'figliastra',
#   'stessa',
#   'figliastra',
#   'faccia',
#   'smetta',
#   'risata',
#   'madre',
#   'pena',
#   'madre',
#   'madre',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'mia',
#   'madre',
#   'riempiva',
#   'madre',
#   'famigliuola',
#   'figliastra',
#   'mano',
#   'madre',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'miseria',
#   'stolidaggine',
#   'madre',
#   'madre',
#   'madre',
#   'nostra',
#   'figliastra',
#   'taccia',
#   'donna',
#   'donna',
#   'afferri',
#   'figliastra',
#   'bestia',
#   'vuol',
#   'vita',
#   'vergogna',
#   'ragione',
#   'madre',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'roba',
#   'roba',
#   'figliastra',
#   'figliastra',
#   'riconosco',
#   'situazione',
#   'sua',
#   'vede',
#   'figliastra',
#   'perfidia',
#   'situazione',
#   'figliastra',
#   'figliastra',
#   'ragione',
#   'vede',
#   "stess'aria",
#   'vedo',
#   'figliastra',
#   'figliastra',
#   'prima',
#   'madre',
#   'figliastra',
#   'madre',
#   'situazione',
#   'sua',
#   'prima',
#   'figliastra',
#   'decisione',
#   'scena',
#   'scena',
#   'passione',
#   'prima',
#   'vanitã\xa0',
#   'vanitã\xa0',
#   'rappresentazione',
#   'rappresentazione',
#   'luce',
#   'scena',
#   'porta',
#   'porta',
#   'figliastra',
#   'figliastra',
#   'greppina',
#   'prego',
#   'figliastra',
#   'busta',
#   'figliastra',
#   'figliastra',
#   'traccia',
#   'stenografia',
#   'stenografia',
#   'carta',
#   'sinistra',
#   'prima',
#   'sua',
#   'faranno',
#   'buca',
#   'fortuna',
#   'madre',
#   'signora',
#   'mano',
#   'figliastra',
#   'prima',
#   'figliastra',
#   'prima',
#   'figliastra',
#   'nostra',
#   'nostra',
#   'loro',
#   'loro',
#   'figura',
#   'voce',
#   'scena',
#   'sua',
#   'sua',
#   'rappresentazione',
#   'figura',
#   'critica',
#   'commedia',
#   'scena',
#   'scena',
#   'figliastra',
#   'dia',
#   'prima',
#   'prima',
#   'figliastra',
#   'figliastra',
#   'vivo',
#   'prima',
#   'prima',
#   'grazia',
#   'scena',
#   'sigaretta',
#   'figliastra',
#   'figliastra',
#   'tenevano',
#   'prima',
#   'rifarã\xa0',
#   'scena',
#   'scena',
#   'figliastra',
#   'protesta',
#   'risposta',
#   'prima',
#   'figliastra',
#   'sua',
#   'mia',
#   'galera',
#   'scena',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'scena',
#   'figliastra',
#   'roba',
#   'figliastra',
#   'crudezza',
#   'figliastra',
#   'madre',
#   'costernazione',
#   'parrucca',
#   'figlia',
#   'figliastra',
#   'madre',
#   'madre',
#   'figliastra',
#   'mamma',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'parrucca',
#   'figliastra',
#   'voce',
#   'scena',
#   'figliastra',
#   'spierã\xa0',
#   'prima',
#   'figliastra',
#   'figliastra',
#   'risposta',
#   'figliastra',
#   'madre',
#   'madre',
#   'sua',
#   'spiritosa',
#   'scena',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'figliastra',
#   'nausea',
#   'prego',
#   'figliastra',
#   'prima',
#   'scena',
#   'prima',
#   'figliastra',
#   'prima',
#   'prego',
#   'rappresentazione',
#   'figliastra',
#   'voce',
#   'figliastra',
#   'figliastra',
#   'signorina',
#   'prima',
#   'prova',
#   'prima',
#   'compiacenza',
#   'prima',
#   'parte',
#   'prima',
#   'prima',
#   'prima',
#   'prima',
#   'prima',
#   'prima',
#   'figliastra',
#   'risata',
#   'figliastra',
#   'accompagnerã\xa0',
#   'figliastra',
#   'risata',
#   'prima',
#   'buffona',
#   'finisca',
#   'finisca',
#   'figliastra',
#   'perdoni',
#   'signorina',
#   'prima',
#   'stessa',
#   'figliastra',
#   'prego',
#   'figliastra',
#   'ragione',
#   'figliastra',
#   'figliastra',
#   'veritã\xa0',
#   'veritã\xa0',
#   'figliastra',
#   'figliastra',
#   'veste',
#   'figliastra',
#   'veritã\xa0',
#   'veritã\xa0',
#   'veritã\xa0',
#   'figliastra',
#   'figliastra',
#   'scena',
#   'figliastra',
#   'figliastra',
#   'caduta',
#   'figliastra',
#   'madre',
#   'commozione',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'madre',
#   'madre',
#   'madre',
#   'figliastra',
#   'vedo',
#   'figliastra',
#   'madre',
#   'mia',
#   'nostra',
#   'madre',
#   'figliastra',
#   'testa',
#   'testa',
#   'testa',
#   'madre',
#   'testa',
#   'madre',
#   'figliastra',
#   'nostra',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'madre',
#   'prego',
#   'mia',
#   'figliastra',
#   'contenti',
#   'contenti',
#   'figliastra',
#   'figliastra',
#   'parte',
#   'prima',
#   'nostra',
#   'prima',
#   'invito',
#   'prima',
#   'sua',
#   'illusione',
#   'massima',
#   'sua',
#   'nostra',
#   'differenza',
#   'disgrazia',
#   'vita',
#   'figliastra',
#   'figliastra',
#   'chiavetta',
#   'stanza',
#   'mamma',
#   'mia',
#   'figliastra',
#   'figliastra',
#   'nostra',
#   'figliastra',
#   'figliastra',
#   'madre',
#   'figliastra',
#   'sua',
#   'sua',
#   'commozione',
#   'luna',
#   'scena',
#   'bambina',
#   'figliastra',
#   'madre',
#   'prego',
#   'figliastra',
#   'terribile',
#   'figliastra',
#   'scaletta',
#   'ribalta',
#   'figliastra',
#   'sua',
#   'sua',
#   'brama',
#   'sua',
#   'madre',
#   'figliastra',
#   'figliastra',
#   'bambina',
#   'bambina',
#   'faccina',
#   'commedia',
#   'commedia',
#   'vasca',
#   'vuoi',
#   'mamma',
#   'bambina',
#   'mano',
#   'sei',
#   'bambina',
#   'calerã\xa0',
#   'vasca',
#   'madre',
#   'seconda',
#   'madre',
#   'madre',
#   'osservo',
#   'sua',
#   'madre',
#   'puã²',
#   'ridã\xa0',
#   'madre',
#   'madre',
#   'madre',
#   'farai',
#   'madre',
#   'madre',
#   'scaletta',
#   'sua',
#   'nostra',
#   'volontã\xa0',
#   'madre',
#   'vasca',
#   'bambina',
#   'madre',
#   'sorellina',
#   'figliastra',
#   'vasca',
#   'bambina',
#   'madre',
#   'confusione',
#   'tenda',
#   'scaletta',
#   'prima',
#   'sala',
#   'prova',
#   'bambina',
#   'figliastra',
#   'scaletta',
#   'risata',
#   'tela'],
#  'madre': ['la',
#   'con',
#   'sarã\xa0',
#   'porterã\xa0',
#   'con',
#   'per',
#   'poi',
#   'e',
#   'e',
#   'allora',
#   'per',
#   'e',
#   'lui',
#   'comune',
#   'anche',
#   'soltanto',
#   'con',
#   'seduta',
#   'ma',
#   'alzandosi',
#   'con',
#   'e',
#   'io',
#   'sbalordita',
#   'e',
#   'con',
#   'non',
#   'ma',
#   'insorgendo',
#   'ã¨',
#   'ma',
#   'tu',
#   "senz'ombra",
#   'eh',
#   'mi',
#   'ma',
#   'e',
#   'e',
#   'ti',
#   'mi',
#   'ã¨',
#   'farã\xa0',
#   'sa',
#   'mi',
#   'dopo',
#   'si',
#   'mi',
#   'e',
#   'la',
#   'che',
#   'da',
#   'il',
#   'â',
#   'che',
#   'al',
#   'sbigottito',
#   'al',
#   'come',
#   'insorgendo',
#   'no',
#   'ma',
#   'e',
#   'presente',
#   'assistendo',
#   'oh',
#   'non',
#   'nel',
#   'accennerã\xa0',
#   'la',
#   'levandosi',
#   'io',
#   'no',
#   'il',
#   'la',
#   'grida',
#   'avventandosi',
#   'dal',
#   'supplichevole',
#   'la',
#   'il',
#   'si',
#   'il',
#   'lã\xa0',
#   'e',
#   'quasi',
#   'si',
#   'se',
#   'che',
#   'sã¬',
#   'il',
#   'alla',
#   'ebbene',
#   'sissignore',
#   'ãˆ',
#   'per',
#   'per',
#   'il',
#   'spaventata',
#   'c',
#   'tremerã\xa0',
#   'e',
#   'con',
#   'con'],
#  'figliastra': ['il',
#   'lo',
#   'di',
#   'con',
#   'giã\xa0',
#   'e',
#   'che',
#   'facendosi',
#   'eh',
#   'schernevole',
#   'no',
#   'subito',
#   'per',
#   'di',
#   'non',
#   'non',
#   'so',
#   'sempre',
#   'anche',
#   'anche',
#   'vile',
#   'eh',
#   'di',
#   'qui',
#   'ah',
#   'sã¬',
#   'si',
#   'lo',
#   'additandolo',
#   'a',
#   'la',
#   'eh',
#   'no',
#   'giã\xa0',
#   'non',
#   'e',
#   'cupa',
#   'perchã©',
#   'e',
#   'sarta',
#   'povera',
#   'indicando',
#   'subito',
#   'buffissimo',
#   'gente',
#   'tu',
#   'con',
#   'per',
#   'con',
#   'tentando',
#   'no',
#   'come',
#   'il',
#   'e',
#   'poi',
#   'sã¬',
#   'esilarata',
#   'ma',
#   'dovrebbe',
#   'ma',
#   'le',
#   'mah',
#   'lei',
#   'subito',
#   'invece',
#   'accorrendo',
#   'e',
#   'per',
#   'lasciando',
#   'graziosamente',
#   'sottovoce',
#   'interrompendolo',
#   'oh',
#   'ridendo',
#   'benissimo',
#   'accorrendo',
#   'al',
#   'andando',
#   'su',
#   'ma',
#   'al',
#   'a',
#   'c',
#   'fa',
#   'subito',
#   'riattacchi',
#   'riattaccando',
#   'ma',
#   'smaniosa',
#   'facendosi',
#   'va',
#   'eh',
#   'divertita',
#   'stia',
#   'e',
#   'vedendo',
#   'venendo',
#   'irresistibilmente',
#   'subito',
#   'rimasta',
#   'urlando',
#   'sã¬',
#   'su',
#   'ah',
#   'interrompendo',
#   'ma',
#   'ma',
#   'e',
#   'no',
#   'gridando',
#   'non',
#   'non',
#   'abbassando',
#   'per',
#   'e',
#   'appena',
#   'ebbene',
#   'signore',
#   'ã¨',
#   "l'ho",
#   'la',
#   'purchã©',
#   'voltandosi',
#   'interrompendo',
#   'non',
#   'perchã©',
#   'ora',
#   'venendo',
#   'ma',
#   'eh',
#   'si',
#   'sissignore',
#   'ah',
#   'cosã¬',
#   'ecco',
#   'e',
#   'sorgendo',
#   'placidamente',
#   'accorrendo',
#   'che',
#   'finirã\xa0',
#   'aspettate',
#   'rimasta',
#   'che'],
#  'figlio': ['il',
#   'il',
#   'di',
#   'resterã\xa0',
#   'che',
#   'lo',
#   'legittimo',
#   'lo',
#   'lã¬',
#   'il',
#   'senza',
#   'sprezzante',
#   'con',
#   'e',
#   'ã¨',
#   'signore',
#   'allevato',
#   'sprezzante',
#   'il',
#   'scrollandosi',
#   'non',
#   'guardandola',
#   'facendosi',
#   'a',
#   'e',
#   'con',
#   'additando',
#   'dice',
#   'e',
#   'il',
#   'se',
#   'io',
#   'bisognerebbe',
#   'avviandosi',
#   'arrivando',
#   'subito',
#   'lo',
#   'resterã\xa0',
#   'subito',
#   'non',
#   'lã\xa0',
#   'lo',
#   'e',
#   'con',
#   'per',
#   'nella',
#   'scorrendo',
#   'voltandosi',
#   'ah',
#   'ãˆ',
#   'nessuna',
#   'violentissimo',
#   'piã¹',
#   'il',
#   'afferrandolo',
#   'colluttando',
#   'additando',
#   "c'ã¨",
#   'dopo',
#   'tra',
#   'esasperato',
#   'con',
#   'guardando',
#   'con',
#   'lentamente',
#   'e',
#   'figlio',
#   'mio',
#   'seguito'],
#  'giovinetto': ['la',
#   'di',
#   'saliranno',
#   'seguiranno',
#   'afferrandolo',
#   'per',
#   'con',
#   'invece',
#   'venga',
#   'eseguirã\xa0',
#   'che',
#   'sbigottito',
#   'ã¨',
#   'sarã\xa0',
#   'e'],
#  'bambina': ['questi',
#   'di',
#   'per',
#   'e',
#   'che',
#   "all'uscita",
#   'mi',
#   'che',
#   'signore',
#   "ch'egli",
#   'lã¬',
#   'quel',
#   'che',
#   'che',
#   'sorprendendolo',
#   'alla',
#   'si',
#   'piace',
#   'e',
#   'e',
#   'il',
#   'risponderã\xa0',
#   'il'],
#  'questi': ['ultimi',
#   'â«sei',
#   'concerti',
#   'quattro',
#   'attaccapanni',
#   'il',
#   'di'],
#  'ultimi': ['due', 'scalini'],
#  'due': ['non',
#   'scalette',
#   'tavolini',
#   'insieme',
#   'scalette',
#   'tavolini',
#   'scalette',
#   'mesi',
#   'creaturine',
#   'mesi',
#   'uomini',
#   'uomini',
#   'anni',
#   'cucendo',
#   'piedi',
#   'fiancate',
#   'fiancate',
#   'dita',
#   'piccoli',
#   'e',
#   'volte',
#   'le',
#   'mesi',
#   'mesi',
#   'di',
#   'piccini',
#   'cipressetti',
#   'cipressetti',
#   'pedani',
#   'scalette',
#   'o',
#   'il'],
#  'non': ['parlano',
#   'ha',
#   'preparato',
#   'ora',
#   'sarã\xa0',
#   'ci',
#   'avrã\xa0',
#   'avete',
#   'sono',
#   'ci',
#   'aver',
#   'si',
#   'si',
#   "s'afflosci",
#   'pertanto',
#   'dovranno',
#   'dia',
#   'calvo',
#   'patito',
#   'deve',
#   "c'ã¨",
#   'abbiamo',
#   "c'ã¨",
#   'voglia',
#   'abbiamo',
#   'han',
#   'ã¨',
#   'ã¨',
#   'aver',
#   'ã¨',
#   'sono',
#   "c'ã¨",
#   'volle',
#   'potã¨',
#   'muore',
#   'muore',
#   'ha',
#   'si',
#   'ridere',
#   'mi',
#   'mi',
#   'posso',
#   'la',
#   'capisco',
#   'ridano',
#   'ridano',
#   'ã¨',
#   'giã\xa0',
#   'ã¨',
#   'potã¨',
#   'poteva',
#   'per',
#   'ã¨',
#   'ã¨',
#   'ã¨',
#   'ã¨',
#   'ã¨',
#   'ã¨',
#   'ci',
#   'ã¨',
#   'puã²',
#   'lo',
#   'ã¨',
#   'parli',
#   'voglio',
#   'per',
#   'fosse',
#   'si',
#   'dice',
#   'ã¨',
#   "l'ho",
#   'ebbe',
#   'arrossisco',
#   'mi',
#   'si',
#   'si',
#   'narro',
#   "c'intendiamo",
#   'so',
#   'che',
#   'ã¨',
#   'potevo',
#   'si',
#   'cercasse',
#   'farmi',
#   'lo',
#   'per',
#   'parendomi',
#   'potei',
#   'tanto',
#   'ti',
#   'so',
#   'mi',
#   'sapevo',
#   'volle',
#   'dico',
#   'ã¨',
#   'darle',
#   'aver',
#   'so',
#   'mi',
#   'abbia',
#   'ancor',
#   'piã¹',
#   'ã¨',
#   'ha',
#   'vederlo',
#   'li',
#   'sente',
#   'posso',
#   'si',
#   'potevo',
#   'mi',
#   'posso',
#   'ã¨',
#   'ã¨',
#   'ã¨',
#   'esser',
#   'doveva',
#   'potevo',
#   'potevo',
#   "c'entro",
#   "c'entri",
#   "c'entro",
#   'voglio',
#   'son',
#   'dico',
#   'so',
#   'posso',
#   'voglio',
#   'vorrei',
#   'puã²',
#   'â«realizzatoâ',
#   'ã¨',
#   'ti',
#   'puã²',
#   "c'entra",
#   'parla',
#   'ã¨',
#   'sa',
#   'ho',
#   'potrebbe',
#   'ci',
#   'basta',
#   'basta',
#   "s'allontanino",
#   'crede',
#   'ci',
#   "c'ã¨",
#   'importa',
#   'importa',
#   "s'immischi",
#   'dubiti',
#   'saprã²',
#   'ci',
#   'recitano',
#   "c'ã¨",
#   "s'immagineranno",
#   'vorremo',
#   'so',
#   'so',
#   'se',
#   'se',
#   'rido',
#   'dicevo',
#   'mi',
#   'so',
#   'non',
#   "m'assomiglia",
#   'abbiamo',
#   'oso',
#   'puã²',
#   'volle',
#   'voglio',
#   'so',
#   'le',
#   "com'io",
#   'perdiamo',
#   'mi',
#   'pretenderã\xa0',
#   'ã¨',
#   'dubiti',
#   'facciamo',
#   'ã¨',
#   'venga',
#   'sarebbe',
#   'si',
#   'son',
#   'sentiamo',
#   'saremo',
#   'si',
#   'ã¨',
#   'badavano',
#   'ã¨',
#   'ã¨',
#   'possono',
#   'era',
#   'importa',
#   'importa',
#   "c'ã¨",
#   'sarã\xa0',
#   'dovrebbe',
#   'faccia',
#   'mi',
#   'potrei',
#   'potendone',
#   'per',
#   'potrei',
#   'a',
#   'badi',
#   'pensi',
#   'scriva',
#   'vi',
#   'si',
#   'ci',
#   'ã¨',
#   'potendo',
#   'riuscendo',
#   'si',
#   'dia',
#   'sarã\xa0',
#   'â«speroâ',
#   'dovrebbe',
#   'riuscirã\xa0',
#   'sto',
#   'sono',
#   'ã¨',
#   'ã¨',
#   'piã¹',
#   'sono',
#   'rida',
#   'rido',
#   'rido',
#   'pensassi',
#   'nego',
#   'ã¨',
#   'ã¨',
#   'ci',
#   'ci',
#   'ci',
#   "c'ã¨",
#   'puã²',
#   'comprendendo',
#   'ã¨',
#   'ã¨',
#   'chiedo',
#   'lo',
#   'lo',
#   'posso',
#   'posso',
#   'capisco',
#   'ã¨',
#   'possono',
#   'sono',
#   'sono',
#   'puã²',
#   'puã²',
#   'dico',
#   'rappresentarlo',
#   'importa',
#   'sentire',
#   'vedi',
#   'importa',
#   'dubiti',
#   'gli',
#   'parlo',
#   'sarã\xa0',
#   'sarã\xa0',
#   'possiamo',
#   'dicano',
#   'adoperino',
#   'puã²',
#   'siamo',
#   'dico',
#   'abbiamo',
#   'soltanto',
#   'ã¨',
#   'volevo',
#   'dico',
#   'esser',
#   'si',
#   'le',
#   'si',
#   'dico',
#   'abbiamo',
#   'cangia',
#   'puã²',
#   "l'ho",
#   "l'ha",
#   'fa',
#   'fa',
#   'pensã²',
#   'si',
#   'ha',
#   'sapeva',
#   'poteva',
#   'come',
#   'ho',
#   'li',
#   'dubiti',
#   'bianco',
#   'fa',
#   'si',
#   'speri',
#   'chiedo',
#   'ho',
#   'ha',
#   'lo',
#   'se',
#   'rappresento',
#   'potrã\xa0',
#   'puã²',
#   'puã²',
#   'vedermelo',
#   'me',
#   'rappresento',
#   'puã²',
#   'per',
#   'bada',
#   'avessi',
#   'risponderã\xa0',
#   'ã¨',
#   "c'ã¨",
#   'nel',
#   'ha',
#   'ha',
#   'la',
#   'siamo',
#   'contento',
#   'mi',
#   'potendone',
#   'fare',
#   'ho',
#   'faccio',
#   'senti',
#   'hai',
#   'ha',
#   'mi',
#   'mi',
#   'volle',
#   'io',
#   'ã¨',
#   'solo',
#   'bastasse',
#   "c'ã¨",
#   'fare',
#   'ci',
#   'potendone',
#   "m'era",
#   'avrã\xa0'],
#  'parlano': ['poi'],
#  'poi': ['evocata',
#   'un',
#   'due',
#   'guardandosi',
#   'chiamando',
#   'altro',
#   'mi',
#   'il',
#   'la',
#   'ammirati',
#   'sdegnato',
#   'rivolgendosi',
#   'fermandosi',
#   'o',
#   'in',
#   'motivo',
#   'ã¨',
#   'subito',
#   'man',
#   'lo',
#   'la',
#   'perchã©',
#   'la',
#   'la',
#   'ã¨',
#   'tornando',
#   'qualche',
#   'coi',
#   'rivolgendosi',
#   'la',
#   'comporci',
#   "dev'esser",
#   'madama',
#   'subito',
#   'dirã\xa0',
#   'riprenderã\xa0',
#   'qua',
#   'faremmo',
#   'al',
#   'io',
#   'esprimendo',
#   'il',
#   'rifacendo',
#   'riprendendo',
#   'a',
#   'le',
#   'in',
#   'negargli',
#   'io',
#   'io',
#   'contemporaneamente',
#   'tirandolo',
#   'rivolgendosi',
#   'tra',
#   'al',
#   'dirã\xa0',
#   'prenderã\xa0',
#   'rifare',
#   'che',
#   'fra',
#   'da',
#   'dal',
#   'giã¹'],
#  'evocata': ['madama', 'attratta'],
#  'madama': ['pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'pace',
#   'ã¨',
#   'pace',
#   'lo',
#   'pace',
#   'pace',
#   'pace',
#   'madama',
#   'pace',
#   'pace',
#   'pace',
#   'madama',
#   'pace',
#   'pace',
#   'pace',
#   'no',
#   'li',
#   'pace',
#   'pace'],
#  'pace': ['gli',
#   'e',
#   'sa',
#   'tutta',
#   'la',
#   'azione',
#   'il',
#   'al',
#   'oh',
#   'il',
#   'megera',
#   'umile',
#   'ebbene',
#   'ã¨',
#   'durante',
#   'che',
#   'che',
#   'parla',
#   'lo',
#   'facendosi',
#   'ah',
#   'viejito',
#   'la',
#   'la',
#   'offesa',
#   'lei',
#   'ah',
#   'che',
#   'piã¹'],
#  'gli': ['attori',
#   'attori',
#   'spettatori',
#   'attori',
#   'assi',
#   'attori',
#   'ã¨',
#   'attori',
#   'attori',
#   'attori',
#   'porgerã\xa0',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'occhi',
#   'occhi',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'ultimi',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'altri',
#   'attori',
#   'occhi',
#   'puã²',
#   "s'appioppa",
#   'altri',
#   'occhi',
#   'occhi',
#   'occhi',
#   'occhi',
#   'occhi',
#   'ospiti',
#   'intrusi',
#   'occhi',
#   'chiede',
#   'altri',
#   'hanno',
#   'altri',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'porgerã\xa0',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'attori',
#   'altri',
#   'atti',
#   'occhi',
#   'attori',
#   'attori',
#   'dissi',
#   'rispondo',
#   'altri',
#   'altri',
#   'bolle',
#   'altri',
#   'dia',
#   'appoggerã\xa0',
#   'occhi',
#   'attori',
#   'fosse',
#   'altri',
#   'attori',
#   'attori',
#   'altri',
#   'sorgerã\xa0',
#   'autori',
#   'propongono',
#   'usci',
#   'attori',
#   'usci',
#   'alberi',
#   "s'appresserã\xa0",
#   'poserã\xa0',
#   'cavasse',
#   'farã\xa0',
#   'scalini',
#   'occhi',
#   'altri',
#   'strapperã\xa0',
#   'occhi',
#   'alberi',
#   'attori',
#   'attori',
#   'attori',
#   'altri'],
#  'attori': ['della',
#   'e',
#   'sgombreranno',
#   'e',
#   'della',
#   'siano',
#   'e',
#   'si',
#   "d'una",
#   'e',
#   'che',
#   'nã©',
#   'rideranno',
#   'torneranno',
#   'della',
#   'che',
#   'le',
#   'si',
#   'fra',
#   'si',
#   'ma',
#   'soddisfatti',
#   'si',
#   'scoppieranno',
#   'prima',
#   'vogliono',
#   'rideranno',
#   'segnatamente',
#   'scoppieranno',
#   'e',
#   'sbalorditi',
#   'accorrendo',
#   'offrirã\xa0',
#   'scaricheranno',
#   'il',
#   'il',
#   'vietasti',
#   'loro',
#   'mi',
#   'resteranno',
#   'sgombreranno',
#   'il',
#   'intorno',
#   'farã\xa0',
#   'sgombrino',
#   'il',
#   'i',
#   'difatti',
#   'i',
#   'il',
#   'dio',
#   'rideranno',
#   'e',
#   'rideranno',
#   'c',
#   'e',
#   'risaliranno',
#   'e',
#   'richiamati',
#   'â«forteâ',
#   'accenneranno',
#   'scoppieranno',
#   'che',
#   'che',
#   'si',
#   'sarã\xa0',
#   'graziosissima',
#   'va',
#   'apparirã\xa0',
#   'il',
#   'il',
#   'e',
#   'vuol',
#   'benissimo',
#   'e',
#   'si',
#   'rimasti',
#   'rideranno',
#   'torneranno',
#   'e',
#   'oh',
#   'se',
#   'a',
#   'che',
#   'si',
#   'quello',
#   'e',
#   'stanno',
#   'in',
#   'la',
#   'da',
#   'da',
#   'se'],
#  'compagnia': ['il', 'uomini', 'la', 'ad', 'mi', 'si'],
#  'direttore': ['capocomico',
#   'di',
#   'capocomico',
#   'capocomico',
#   'di',
#   'di',
#   'di',
#   'per',
#   'di',
#   'di',
#   'di',
#   'per',
#   'di',
#   'il',
#   'capocomico',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'permette',
#   'capocomico',
#   'ma',
#   'di',
#   'di',
#   'seguiterã\xa0',
#   'di',
#   'capocomico',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'di',
#   'e',
#   'il'],
#  'capocomico': ['la',
#   "l'uscere",
#   'e',
#   'altri',
#   'il',
#   'lettere',
#   'porgendogli',
#   'battendo',
#   'al',
#   'lei',
#   'borbottando',
#   'si',
#   'alla',
#   'seccato',
#   'al',
#   'volgendosi',
#   'alzandosi',
#   'debbo',
#   'ma',
#   'ma',
#   'urtato',
#   'balzando',
#   'tornandosene',
#   'ma',
#   "l'arrivo",
#   'di',
#   'e',
#   'di',
#   'fra',
#   'ma',
#   'tranne',
#   'lor',
#   'ma',
#   'ma',
#   'alzandosi',
#   'subito',
#   'il',
#   'sta',
#   'con',
#   'e',
#   'prima',
#   'ma',
#   'gridando',
#   'sorridente',
#   'subito',
#   'tutto',
#   'ironico',
#   'ma',
#   'seccato',
#   'e',
#   'come',
#   'irato',
#   'peggio',
#   'vede',
#   'signore',
#   'qua',
#   'soprappreso',
#   'e',
#   'non',
#   'lo',
#   'che',
#   'giã\xa0',
#   'creda',
#   'io',
#   'a',
#   'no',
#   'la',
#   'ma',
#   'al',
#   'e',
#   'la',
#   'ella',
#   'ridiscenderã\xa0',
#   'in',
#   'ma',
#   'sarã\xa0',
#   'le',
#   'veniamo',
#   'subito',
#   'eccola',
#   'e',
#   'eh',
#   'benissimo',
#   'stai',
#   'seguitando',
#   'ci',
#   'sono',
#   'eh',
#   'lasciamo',
#   'io',
#   'perchã©',
#   'ma',
#   'giã\xa0',
#   'risalendo',
#   'mi',
#   'sã¬',
#   'e',
#   'coi',
#   'su',
#   'disponga',
#   "s'intenderã\xa0",
#   'al',
#   'ma',
#   'adesso',
#   "c'ã¨",
#   'va',
#   'alla',
#   'al',
#   'seguiterã\xa0',
#   'al',
#   'con',
#   'ma',
#   'seguitando',
#   'prevenendola',
#   'niente',
#   'una',
#   'e',
#   'oh',
#   'ah',
#   'non',
#   'ma',
#   'ma',
#   'irato',
#   'alla',
#   'ma',
#   "nient'affatto",
#   'troncando',
#   'oh',
#   'si',
#   'e',
#   'non',
#   'e',
#   'su',
#   'con',
#   'e',
#   'giã\xa0',
#   'che',
#   'ma',
#   'schizzeranno',
#   'vincendo',
#   'e',
#   'ebbene',
#   'oh',
#   'come',
#   'costernatissimo',
#   'fermandolo',
#   'gridando',
#   'quasi',
#   'ma',
#   'accorso',
#   'non',
#   'non',
#   'sceso',
#   'piano',
#   'subito',
#   'interrompendo',
#   'abbia',
#   'alla',
#   'ah',
#   'alla',
#   'infuriato',
#   'ma',
#   'ma',
#   'dice',
#   'ma',
#   'â«ah',
#   'ma',
#   'crollerã\xa0',
#   'voltandosi',
#   'al',
#   'alla',
#   'lei',
#   'risalendo',
#   'strano',
#   'eh',
#   'ma',
#   'ma',
#   'e',
#   'dunque',
#   'la',
#   'bello',
#   'ma',
#   'lo',
#   'ponendosi',
#   'ma',
#   'ma',
#   'seccato',
#   'non',
#   'benissimo',
#   'ma',
#   'ma',
#   'ma',
#   'ma',
#   'arretrando',
#   'ammirato',
#   'il',
#   'e',
#   'guardando',
#   'sarã\xa0',
#   'scrollandosi',
#   'spazientito',
#   'spazientito',
#   'la',
#   'vogliamo',
#   'perchã©',
#   'eh',
#   'sã¬',
#   'stordito',
#   'e',
#   "l'illusione",
#   'ecco',
#   'stordito',
#   'e',
#   'turbato',
#   'le',
#   'seccato',
#   'rivolgendosi',
#   'giã\xa0',
#   'ha',
#   'senza',
#   'rivolgendosi',
#   'ah',
#   'piã¹',
#   'ma',
#   'con',
#   'ma',
#   'per',
#   'andiamo',
#   'giã\xa0',
#   'non',
#   'brava',
#   'le',
#   'faremo',
#   'alla',
#   'un',
#   'ma',
#   'alla',
#   'subito',
#   'che',
#   'come',
#   'me',
#   'permette',
#   'lo',
#   'per',
#   'immagini',
#   'fremendo',
#   'benissimo',
#   'ma',
#   'per',
#   "all'attor",
#   'si',
#   'ma',
#   'ma',
#   'e',
#   'ma',
#   'incitandolo',
#   'spingendolo',
#   'piano',
#   'al',
#   'tra',
#   'e',
#   'non',
#   'rifiaterã\xa0',
#   'vedendole'],
#  'prima': ['attrice',
#   'volta',
#   'uno',
#   'scena',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'leone',
#   'diceva',
#   'stupefatti',
#   'sbalordito',
#   'attrice',
#   'strofa',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'dal',
#   'poi',
#   'farci',
#   'volta',
#   'ad',
#   'appena',
#   'attrice',
#   'il',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'scena',
#   'attrice',
#   'attrice',
#   'scena',
#   'attrice',
#   'attrice',
#   'che',
#   'venga',
#   'volta',
#   'ecco',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'la',
#   'volta',
#   'attrice',
#   'attrice',
#   'attrice',
#   'volta',
#   'attrice',
#   'attrice',
#   'a',
#   'attrice',
#   'attrice',
#   'attrice',
#   'attrice',
#   'che',
#   "ch'io",
#   'in',
#   'stabilito',
#   'attrice',
#   'attrice',
#   'attrice',
#   'il',
#   'quello',
#   'la',
#   'attrice',
#   'lentamente',
#   'avanti'],
#  'attrice': ['il',
#   'il',
#   'la',
#   'no',
#   'mi',
#   'che',
#   'lei',
#   'io',
#   'si',
#   'vogliono',
#   'ce',
#   'che',
#   'scusi',
#   'per',
#   'ah',
#   'ma',
#   'lei',
#   'indignata',
#   'subito',
#   'si',
#   'risentita',
#   'c',
#   'c',
#   'fra',
#   'cosã¬',
#   'ma',
#   'e',
#   'aspetti',
#   'sarã²',
#   'e',
#   'se',
#   'â«buon',
#   'â«buon',
#   'di',
#   'â«non',
#   'e',
#   'â«no',
#   'il',
#   'solleverã\xa0',
#   'indignata',
#   'ma',
#   'e',
#   'interrompendo',
#   'come',
#   'rientrando'],
#  'primo': ['attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'stupore',
#   'attore',
#   'attore',
#   'abbozzo',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'determinã²',
#   'atto',
#   'atto',
#   'simulacro',
#   'attore',
#   'attore',
#   'attore',
#   'attore',
#   'scalino'],
#  'attore': ['la',
#   'al',
#   'ma',
#   'griderã\xa0',
#   'sissignore',
#   'aprendo',
#   'non',
#   'oh',
#   'ai',
#   'civettare',
#   'il',
#   'ma',
#   'ci',
#   'vorrei',
#   'che',
#   'ma',
#   'io',
#   'mah',
#   'e',
#   'e',
#   'con',
#   'concluda',
#   'quasi',
#   'ma',
#   'di',
#   'possiamo',
#   'oh',
#   'con',
#   'sentendo',
#   'â«buon',
#   'scoppierã\xa0',
#   'facendosi',
#   'â«buon',
#   'rifacendo',
#   'accennando',
#   'per',
#   'mi',
#   'insomma',
#   "â«c'ã¨",
#   'a',
#   'â«piã¹',
#   'dirã\xa0',
#   'e',
#   'la',
#   'si',
#   'con',
#   'che',
#   'rientrando'],
#  'seconda': ['donna', 'volta', 'donna', 'donna', 'donna', 'donna', 'donna'],
#  'donna': ["l'attrice",
#   'e',
#   'velata',
#   'ã¨',
#   'indicherã\xa0',
#   'il',
#   'restarmi',
#   'indicherã\xa0',
#   'e',
#   'piã¹',
#   'ecco',
#   'infatti',
#   'lei',
#   'io',
#   'e',
#   'e',
#   'ah',
#   'va'],
#  "l'attrice": ['giovane',
#   'giovane',
#   'giovane',
#   'giovane',
#   'giovane',
#   'che',
#   'giovane'],
#  'giovane': ["l'attor",
#   'altri',
#   'indicando',
# ...
#   'che',
#   'questo',
#   'male',
#   'al',
#   'a',
#   'signori',
#   'scene',
#   'il',
#   'perdere'],
#  'possa': ['comperare'],
#  'comperare': ['in'],
#  'qualsiasi': ['bottega', 'sartoria'],
#  'bottega': ['della'],
#  'cittã\xa0': ['e'],
#  'tagliato': ['e'],
#  'cucito': ['in'],
#  'sartoria': ['il'],
#  'cinquantina': ['stempiato'],
#  'stempiato': ['ma'],
#  'calvo': ['fulvo'],
#  'fulvo': ['di'],
#  'pelo': ['con'],
#  'baffetti': ['folti'],
#  'folti': ['quasi'],
#  'acchiocciolati': ['attorno'],
#  'ancor': ['fresca', 'tanto'],
#  'fresca': ['aperta'],
#  'aperta': ['spesso', 'protesta'],
#  'spesso': ['a'],
#  'sorriso': ['incerto', 'e', 'ma', 'come'],
#  'incerto': ['e'],
#  'vano': ['pallido'],
#  'pallido': ['segnatamente', 'molto', 'in', 'sorriso'],
#  'segnatamente': ["nell'ampia", 'i'],
#  "nell'ampia": ['fronte'],
#  'fronte': ['occhi', "all'altro", 'sorditã\xa0', "all'altro", 'e'],
#  'azzurri': ['ovati'],
#  'ovati': ['lucidissimi'],
#  'lucidissimi': ['e'],
#  'arguti': ['vestirã\xa0'],
#  'vestirã\xa0': ['calzoni', 'umilmente', 'a'],
#  'calzoni': ['chiari'],
#  'giacca': ['scura'],
#  'scura': ['a'],
#  'mellifluo': ['a', 'oh', 'onoratissimo'],
#  'scatti': ['aspri'],
#  'aspri': ['e'],
#  'duri': ['la'],
#  'atterrita': ['e'],
#  'schiacciata': ['da'],
#  'peso': ['intollerabile', 'di'],
#  'intollerabile': ['di', 'il'],
#  'vergogna': ['e',
#   'figlia',
#   'la',
#   'ãˆ',
#   'andarne',
#   'ãˆ',
#   'lã\xa0',
#   'e',
#   'niente',
#   'indicherã\xa0',
#   'e'],
#  "d'avvilimento": ['velata'],
#  'velata': ['da', 'di'],
#  'fitto': ['crespo'],
#  'crespo': ['vedovile'],
#  'vedovile': ['vestirã\xa0'],
#  'umilmente': ['di'],
#  'nero': ['e', 'e', 'cosã¬', 'il', 'la', 'e'],
#  'solleverã\xa0': ['il', 'il', 'un'],
#  'velo': ['mostrerã\xa0', 'che', 'la'],
#  'mostrerã\xa0': ['un', 'dispetto', "l'abito"],
#  'viso': ['non', 'e'],
#  'patito': ['ma'],
#  'terrã\xa0': ['sempre', 'discosto', 'conto'],
#  'bassi': ['la'],
#  'diciotto': ['anni'],
#  'anni': ['sarã\xa0', 'vestito', 'vestita', 'alto', 'fu', 'di', 'il'],
#  'spavalda': ['quasi', 'cosã¬'],
#  'impudente': ['bellissima'],
#  'bellissima': ['vestirã\xa0'],
#  'lutto': ['anche', 'come', 'giã\xa0', 'la', 'e', 'nel', 'recente'],
#  'vistosa': ['eleganza'],
#  'eleganza': ['mostrerã\xa0', 'di'],
#  'dispetto': ['per', 'di', 'la', 'non'],
#  "l'aria": ['timida', 'spigliata', 'di', 'il'],
#  'timida': ['afflitta'],
#  'afflitta': ['e'],
#  'smarrita': ['del', 'con'],
#  'fratellino': ['squallido', 'che'],
#  'squallido': ['giovinetto'],
#  'quattordici': ['anni'],
#  'vestito': ["anch'egli", 'di'],
#  "anch'egli": ['di'],
#  'vivace': ['tenerezza'],
#  'tenerezza': ['invece', 'della'],
#  'invece': ['per',
#   'di',
#   'per',
#   'vede',
#   'accorrerã\xa0',
#   'una',
#   'non',
#   "l'unica",
#   'tutti',
#   'di',
#   "d'ammazzarmi"],
#  'sorellina': ['bambina', 'affogata'],
#  'circa': ['quattro'],
#  'quattro': ['anni', 'figli', 'volte', 'e'],
#  'fascia': ['di', 'verde'],
#  'seta': ['nera', 'rossa'],
#  'nera': ['alla'],
#  'vita': ['il',
#   'ã¨',
#   'sulla',
#   'qua',
#   'in',
#   'fortunata',
#   'signore',
#   'cosã¬',
#   'questo',
#   'e',
#   'creata',
#   'dentro',
#   'che',
#   'non',
#   'sua',
#   'e',
#   'non',
#   'che'],
#  'ventidue': ['anni'],
#  'alto': ['quasi', 'con'],
#  'irrigidito': ['in'],
#  'contenuto': ['sdegno', 'ribrezzo'],
#  'sdegno': ['per',
#   'crescente',
#   'e',
#   'degli',
#   'â«quella',
#   "d'ansia",
#   'e',
#   'del',
#   'ma'],
#  "un'accigliata": ['indifferenza'],
#  'indifferenza': ['per'],
#  'porterã\xa0': ['un', 'davanti'],
#  'soprabito': ['viola'],
#  'viola': ['e'],
#  'lunga': ['fascia', 'e', 'pausa'],
#  'verde': ['girata', 'la', 'era', 'con', 'che'],
#  'girata': ['attorno'],
#  'collo': ["l'uscere", 'mi'],
#  'mano': ['scusi',
#   'e',
#   'alla',
#   'la',
#   'la',
#   'attratto',
#   'cosã¬',
#   'che',
#   'alla',
#   'e',
#   'levata',
#   'sotto',
#   'sulla',
#   'sulla',
#   'i',
#   'sulla',
#   'che',
#   'gli',
#   'dalla'],
#  'commendatore': ['il'],
#  'scatto': ['sgarbato',
#   'iroso',
#   'indignata',
#   'vergogna',
#   'non',
#   'alzandosi',
#   'parandoglisi'],
#  'sgarbato': ['che'],
#  "c'ã¨": ["l'uscere",
#   'nessun',
#   "l'autore",
#   'lã\xa0',
#   'poi',
#   'materia',
#   'in',
#   'quello',
#   'il',
#   'la',
#   'una',
#   'quello',
#   'un',
#   'e',
#   "l'attore",
#   'la',
#   'qualcuno',
#   'un',
#   'bisogno',
#   'venuta',
#   'soltanto',
#   'anche',
#   'da',
#   'quello',
#   'stata',
#   'lei',
#   'voluto',
#   'stato',
#   'stato'],
#  'timidamente': ['ci'],
#  'certi': ['signori', 'rimorsi'],
#  'chiedono': ['di'],
#  'stupiti': ['a'],
#  'provo': ['e', 'quello'],
#  'sapete': ['bene'],
#  'durante': ['la', 'la'],
#  'deve': ['passar',
#   'deve',
#   'darlo',
#   'aver',
#   'ridursi',
#   'forse',
#   'culminare',
#   'finir',
#   'dare',
#   'rappresentare',
#   'restar',
#   'accadere',
#   'deve',
#   'restar'],
#  'passar': ['nessuno'],
#  'nessuno': ['rivolgendosi', 'meglio', 'dei', 'ha', 'le', 'il'],
#  'lor': ['signori',
#   'signori',
#   'signori',
#   'signori',
#   'signori',
#   'signori',
#   'signori',
#   'signori'],
#  'vogliono': ['il',
#   'scherzare',
#   'loro',
#   'vivere',
#   'la',
#   'sapere',
#   'le',
#   'guastare',
#   'e'],
#  'facendosi': ['avanti',
#   'voce',
#   'avanti',
#   'avanti',
#   'avanti',
#   'avanti',
#   'avanti',
#   'avanti',
#   'avanti',
#   'forza',
#   'avanti'],
#  'seguito': ['dagli', 'un', 'dalle', 'con', 'dalla'],
#  'dagli': ['altri', 'oggetti', 'attori'],
#  'fino': ['a', 'alla', 'ma', 'a', 'ad', 'alla'],
#  'autore': ['il',
#   'che',
#   'il',
#   'perchã©',
#   'forse',
#   'il',
#   'che',
#   'questo',
#   'che',
#   'che'],
#  'stordito': ['e', 'ma', 'e', 'guardando'],
#  'irato': ["d'un", 'silenzio', 'che'],
#  'qualunque': ['signore'],
#  'signore': ['il',
#   'potremmo',
#   'le',
#   'lei',
#   'per',
#   'ã¨',
#   'che',
#   'dimostrarle',
#   'e',
#   'interessantissimi',
#   'perchã©',
#   'il',
#   'almeno',
#   'gli',
#   'la',
#   'peggio',
#   'in',
#   'la',
#   'la',
#   'ella',
#   'per',
#   'potente',
#   'me',
#   'fui',
#   'per',
#   'una',
#   'fremendo',
#   'il',
#   'e',
#   'se',
#   'che',
#   'creda',
#   'fino',
#   "c'era",
#   'ero',
#   'ma',
#   'il',
#   'in',
#   'creda',
#   'andata',
#   'ma',
#   'passione',
#   'perchã©',
#   'nuovo',
#   'ritornano',
#   'se',
#   'impreveduto',
#   'ciascuno',
#   'ã¨',
#   'perchã©',
#   'ma',
#   'servano',
#   'se',
#   'che',
#   'lei',
#   'pretendere',
#   'nella',
#   'â«tantiâ',
#   'io',
#   'che',
#   'vorrei',
#   'una',
#   'quando',
#   'quello',
#   'che',
#   'il',
#   'nati',
#   'quel',
#   'che',
#   'vedrã\xa0',
#   'non',
#   'il',
#   'ma',
#   'la',
#   'ma',
#   'per',
#   'ma',
#   "s'inchinerã\xa0",
#   "s'adoperi",
#   'indicherã\xa0',
#   'il',
#   'mi',
#   'gli',
#   'forse',
#   'se',
#   'allude',
#   "m'ha",
#   'parla',
#   'ci',
#   'il',
#   'me',
#   'il',
#   'guardi',
#   'non',
#   'tocca',
#   'la',
#   'â',
#   'ammiro',
#   'lã\xa0',
#   'guardi',
#   'della',
#   'bisogna',
#   'il',
#   'il',
#   'quella',
#   'non',
#   'io',
#   'se',
#   'se',
#   'lei',
#   'non',
#   'tutta',
#   'non',
#   'il',
#   'per',
#   'forse',
#   'una',
#   'lã\xa0',
#   'puã²',
#   'se',
#   'ripensando',
#   'farle',
#   'il',
#   'vede',
#   'realtã\xa0',
#   'perchã©',
#   'per',
#   'per',
#   'si',
#   'felice',
#   'gli',
#   'quando',
#   'il',
#   'non',
#   'io',
#   'io',
#   'ãˆ',
#   'il'],
#  'nessun': ['autore'],
#  'abbiamo': ['in', 'tempo', 'tutti', 'tanti', 'la', 'altra', 'altra'],
#  'nuova': ['la', 'qualcuno', 'famigliuola', 'sã¬', 'come', 'buon'],
#  'gaja': ['vivacitã\xa0'],
#  'salendo': ['di'],
#  'furia': ['la', 'dilaniatrice'],
#  'scaletta': ['tanto', 'e', 'e', 'ma', 'del', 'tra', 'saranno', 'correrã\xa0'],
#  'meglio': ['tanto',
#   'allora',
#   'di',
#   'non',
#   'rivolgendosi',
#   'una',
#   'la',
#   'anzi',
#   'viene',
#   'per',
#   'adesso',
#   'il'],
#  'potremmo': ['esser', 'essere'],
#  'esser': ['noi',
#   'lei',
#   'qui',
#   'tutti',
#   'io',
#   'subito',
#   'subito',
#   'pronto',
#   'cosã¬',
#   'la',
#   'â«nessunoâ',
#   'altra',
#   'da',
#   'grato'],
#  'noi': ['la',
#   'ripeto',
#   'il',
#   'qua',
#   "l'attor",
#   'il',
#   'signore',
#   'siamo',
#   'e',
#   'tutti',
#   'tre',
#   "l'attor",
#   'ragazze',
#   'la',
#   'veda',
#   'â«unoâ',
#   'lui',
#   'il',
#   'come',
#   'il',
#   'a',
#   'che',
#   'dovrebbe',
#   'pensiamo',
#   'signore',
#   'invitando',
#   'sul',
#   'non',
#   'stando',
#   'il',
#   'pare',
#   'come',
#   'siamo',
#   'adesso',
#   'quello',
#   'tanto',
#   'ã¨',
#   'mi',
#   'come',
#   'indicherã\xa0',
#   'ã¨',
#   'del',
#   'indicherã\xa0',
#   'il',
#   'immagini',
#   'ora',
#   'che',
#   'faremo',
#   'non',
#   'stessi'],
#  'vivaci': ['commenti'],
#  'risate': ['degli'],
#  'senti': ['senti', 'il', 'come'],
#  'seguendo': ['sul'],
#  "l'autore": ['al', 'che', 'io', 'io', 'non', 'non'],
#  'primi': ['scalini'],
#  'scalini': ['della', 'e', 'poi'],
#  'resteranno': ['lã¬', 'come', 'per', 'impressionatissimi', 'un'],
#  'resterã\xa0': ['sotto',
#   'alla',
#   'in',
#   'come',
#   'alzato',
#   'al',
#   'proteso',
#   'anche'],
#  'scontroso': ['il'],
#  'scherzare': ['il'],
#  'dice': ['mai',
#   'il',
#   'per',
#   'perchã©',
#   'nulla',
#   'di',
#   "all'uomo",
#   'che',
#   'che',
#   'il',
#   'sul',
#   'perchã©',
#   'la',
#   'forse',
#   'a',
#   'â«ã¨',
#   'â«non',
#   'la',
#   'il'],
#  'portiamo': ['al', 'in', 'ancora'],
#  'contrario': ['un', 'cioã¨'],
#  'dramma': ['doloroso',
#   'doloroso',
#   'ã¨',
#   'perchã©',
#   'signore',
#   'non',
#   'potente',
#   'viene',
#   'scoppia',
#   'per',
#   'acquisterã\xa0',
#   'la',
#   'il',
#   'cosã¬',
#   'che',
#   'il',
#   'scoppiare'],
#  'doloroso': ['la', 'come'],
#  'essere': ['la', 'per', 'accolto', 'qua', 'una', 'cosã¬', 'cosã¬', 'stata'],
#  'fortuna': ['il', 'ã¨', 'non', 'ã¨', 'la', "d'averli"],
#  'facciano': ['il', 'silenzio', 'questa', 'sentire', 'silenzio'],
#  "d'andar": ['via'],
#  'perdere': ['coi', 'coi', 'una'],
#  'coi': ['pazzi',
#   'pazzi',
#   'sei',
#   'personaggi',
#   'cappellini',
#   'suoi',
#   'suoi',
#   'chiodi'],
#  'pazzi': ['il', 'il', 'mentre', 'o'],
#  'ferito': ['e', 'mi', 'con', "s'ã¨", 'davvero'],
#  'sa': ['bene',
#   'perchã©',
#   'signore',
#   'perchã©',
#   'con',
#   'scrivere',
#   'bene',
#   'signore',
#   'il',
#   'perchã©',
#   'che',
#   'tornando',
#   'che',
#   'e',
#   'che',
#   'anzi',
#   'che',
#   'come',
#   'come',
#   'dire',
#   'che',
#   'dire',
#   'dove',
#   'il'],
#  'piena': ["d'infinite"],
#  "d'infinite": ['assurditã\xa0'],
#  'assurditã\xa0': ['le'],
#  'quali': ['sfacciatamente', 'per', 'se'],
#  'sfacciatamente': ['non'],
#  'han': ['neppure', 'determinato', 'saputo'],
#  'neppure': ['bisogno', 'di'],
#  'parer': ['verosimili', 'vero'],
#  'verosimili': ['perchã©', 'perchã©'],
#  'vere': ['il', 'ma'],
#  'diavolo': ['dice', 'tutti'],
#  'puã²': ['stimarsi',
#   'sapere',
#   'ridersi',
#   'saperne',
#   'nascere',
#   'attestare',
#   'dare',
#   'vedere',
#   'dunque',
#   'soffrirlo',
#   'essere',
#   'sapere',
#   'dar',
#   'andare',
#   'stare',
#   'anche',
#   'rinunziarvi',
#   'veramente',
#   'rappresentarmi',
#   'vedere',
#   'comprendere',
#   'dunque',
#   'sempre',
#   'non',
#   'cangiare',
#   'cangiare',
#   'cangiare',
#   'esser',
#   'vede',
#   'deve',
#   'andarsene',
#   'aver',
#   'costringere',
#   'costringermi',
#   'fare'],
#  'stimarsi': ['realmente'],
#  'realmente': ['una', 'sono', 'per', 'avvenuto'],
#  'pazzia': ['sissignore', 'ã¨', "bell'e"],
#  'sforzarsi': ['di'],
#  'cioã¨': ['di', 'sotto'],
#  'crearne': ['di'],
#  'pajano': ['vere'],
#  'permetta': ['di', 'signore', 'il'],
#  'farle': ['osservare', 'poi', 'sollevare', 'vedere'],
#  'osservare': ['che', 'con'],
#  'pur': ["l'unica", "senz'amore", 'senza', 'farla'],
#  "l'unica": ['ragione', 'nostra'],
#  'mestiere': ['gli', 'da'],
#  'agiteranno': ['sdegnati'],
#  'sdegnati': ['il'],
#  'squadrandolo': ['ah'],
#  'ah': ['sã¬',
#   'bello',
#   'ã¨',
#   'miseria',
#   'che',
#   'se',
#   'benissimo',
#   'le',
#   'guarda',
#   'ã¨',
#   'no',
#   'no',
#   'me',
#   'ma',
#   'giã\xa0',
#   'io',
#   'non',
#   'capisco',
#   'comodo',
#   'benissimo',
#   'sã¬',
#   'la',
#   'nel',
#   'dico',
#   'benissimo',
#   'ma',
#   'ma',
#   'dove',
#   'e',
#   'si',
#   'non'],
#  'sembra': ['un', 'di'],
#  'nostro': ['il', 'vanto', 'atto', 'dramma', 'autore'],
#  'eh': ['far',
#   'per',
#   'altro',
#   'ma',
#   'sfido',
#   'altro',
#   'ma',
#   'novissima',
#   'via',
#   'quasi',
#   'puntuali',
#   'cosã¬',
#   'giã\xa0',
#   'dico',
#   'ciã\xa0',
#   'via',
#   'via',
#   'ma',
#   'sfido',
#   'giã\xa0',
#   'ma',
#   'finta',
#   'ma',
#   'perdio'],
#  'vero': ['quello',
#   'delitto',
#   'sviene',
#   'la',
#   'la',
#   'non',
#   'la',
#   'al',
#   'lo',
#   'dillo',
#   'signore',
#   'non',
#   'io',
#   'la',
#   'signore',
#   'ã¨',
#   'non',
#   'ce',
#   'la',
#   'nome',
#   'madama',
#   'che',
#   'vedo',
#   'â',
#   'â',
#   'che',
#   'ã¨',
#   'ma',
#   'ma',
#   'il',
#   'io',
#   'perchã©',
#   'e',
#   "anch'io",
#   'la',
#   'signore',
#   'signore',
#   'questo',
#   'se',
#   'ãˆ'],
#  'quello': ['che',
#   'stupido',
#   'che',
#   'lã\xa0',
#   'non',
#   'la',
#   'lã¬',
#   'lã¬',
#   'di',
#   "dell'uomo",
#   'diversissimi',
#   'solo',
#   'che',
#   'che',
#   'verde',
#   'che',
#   'piccolo',
#   'il',
#   'degli',
#   'che',
#   'che',
#   'che',
#   'degli',
#   'di',
#   'di',
#   'spettacolo',
#   'lã¬',
#   'lã¬',
#   'scrittojo',
#   'lã¬',
#   'lã¬',
#   'che',
#   'lã¬',
#   'che',
#   'che',
#   'che',
#   'sguardo'],
#  'ufficio': ['dar'],
#  'fantasticati': ['il'],
#  'dello': ['sdegno', 'stessissimo'],
#  'crescente': ['dei', 'apprensione'],
#  'suoi': ['attori',
#   'attori',
#   'compagni',
#   'modi',
#   'attori',
#   'i',
#   'attori',
#   'travagli',
#   'â«nobiliâ',
#   'tormenti',
#   'attori',
#   'attori',
#   'attori',
#   'per',
#   'braccini',
#   'attori',
#   'attori'],
#  'prego': ['di', 'di', 'non', 'signorina', 'a', 'e', 'a', 'signore', 'me'],
#  'credere': ['che', "un'ingrata"],
#  'professione': ['del', 'se'],
#  'comico': ['caro'],
#  'caro': ['signore', 'il', 'signore', 'signore', 'signore', 'signore'],
#  'nobilissima': ['professione'],
#  'oggi': ['come', 'i', 'respira'],
#  'commediografi': ['nuovi'],
#  'nuovi': ['ci'],
#  'danno': ['da', 'loro', 'i', 'a'],
#  'stolide': ['commedie'],
#  'fantocci': ['invece'],
#  'sappia': ['che'],
#  'vanto': ['aver'],
#  'dato': ['vita', 'a'],
#  'queste': ['tavole',
#   'due',
#   'maledette',
#   'son',
#   'migliori',
#   'dita',
#   'ultime',
#   'tavole',
#   'anatrelle'],
#  'tavole': ['a', 'di'],
#  'opere': ['immortali'],
#  'immortali': ['gli'],
#  'soddisfatti': ['approveranno'],
#  'approveranno': ['e'],
#  'applaudiranno': ['il', 'sghignazzando'],
#  'interrompendo': ['e', 'rivolto', 'come', 'con', 'sdegnata'],
#  'incalzando': ['con'],
#  'foga': ['ecco'],
#  'benissimo': ['a',
#   'ma',
#   'il',
#   'lo',
#   'sã¬',
#   'conosce',
#   'la',
#   'come',
#   'va',
#   'poi',
#   'dunque',
#   'in',
#   'per',
#   'e',
#   'sã¬',
#   'e',
#   'benissimo',
#   'effetto',
#   'e',
#   'benissimo',
#   'rivolgendosi',
#   'rivolgendosi'],
#  'esseri': ['vivi'],
#  'vivi': ['piã¹',
#   'di',
#   'come',
#   'quassã¹',
#   'non',
#   'germi',
#   'davanti',
#   'davanti',
#   'cosã¬',
#   'vivi',
#   'veramente'],
#  'respirano': ['e'],
#  'vestono': ['panni'],
#  'panni': ['meno'],
#  'meno': ['reali', 'il', 'della', 'mah', 'vera', 'caricato', 'il'],
#  'forse': ['ma',
#   'abituati',
#   'perchã©',
#   'in',
#   'che',
#   'ma',
#   'la',
#   'potrã\xa0',
#   'indovino',
#   'preparandole',
#   'scappar',
#   'per',
#   'un',
#   'cavarne',
#   'come',
#   'lei',
#   'ã¨',
#   'a'],
#  'veri': ['siamo'],
#  'stessissimo': ['parere'],
#  'parere': ['gli'],
#  'guardano': ['tra'],
#  'sbalorditi': ['il', 'e'],
#  'diceva': ['il', 'che'],
#  'dicevo': ['signore', 'per', 'per', 'alla', 'io'],
#  'gridato': ['di', 'allora'],
#  'sapere': ['che', 'che', 'serve', 'chi', 'per', 'signore', 'perã²'],
#  'natura': ['si'],
#  'serve': ['da', 'in', 'tutto'],
#  'strumento': ['della', 'della'],
#  'umana': ['per', 'che'],
#  'proseguire': ['piã¹'],
#  'alta': ['la', 'materia'],
#  'opera': ['di', 'mia'],
#  'creazione': ['il', 'la', 'quando'],
#  'vuol': ['concludere',
#   'concertare',
#   'riconoscere',
#   'dare',
#   'dare',
#   'fare',
#   'piã¹',
#   'salvare',
#   'dare',
#   'niente',
#   'fare',
#   'fare',
#   'fare',
#   'esser',
#   'capire',
#   'niente',
#   'dire',
#   'fare',
#   'subito',
#   'dire',
#   'risparmiargli',
#   'vedere',
#   'concludere',
#   'vedere',
#   'lei',
#   'far'],
#  'concludere': ['con', 'con'],
#  'questo': ['il',
#   'va',
#   'qua',
#   'dramma',
#   'amorino',
#   'rapidamente',
#   'il',
#   'povero',
#   'ã¨',
#   'punto',
#   'per',
#   'punto',
#   'lei',
#   'punto',
#   'ã¨',
#   'ã¨',
#   'ã¨',
#   'come',
#   'sentimento',
#   'ã¨',
#   'se',
#   'â«unoâ',
#   'questo',
#   'signore',
#   'il',
#   'tuo',
#   "m'interessa",
#   'un',
#   'ã¨',
#   'penseremo',
#   'veda',
#   'corpo',
#   'chi',
#   'ã¨',
#   'prodigio',
#   'vede',
#   'â«viã¨chio',
#   'signore',
#   'per',
#   'sulla',
#   'farne',
#   'solo',
#   'sempre',
#   'primo',
#   'in',
#   'dispetto',
#   'secondo',
#   "s'ã¨",
#   'infatti',
#   'giuoco',
#   'il',
#   'senza',
#   'non',
#   'lo',
#   'personaggio',
#   'ragazzo',
#   'suo',
#   'carina',
#   'non',
#   'ã¨',
#   'ã¨'],
#  'niente': ['signore',
#   'fa',
#   'lo',
#   'stare',
#   'al',
#   'niente',
#   'il',
#   'signore',
#   'la'],
#  'dimostrarle': ['che'],
#  ...}

# %%
import random
var= input("scrivi la prima parola: ")

lunghezza_frase= int(input("scrivi quanto vuoilunga la frase: "))
# Out:
# scrivi la prima parola: frase
# scrivi quanto vuoilunga la frase: 30

# %%
print(f"la frase è:") 
stringa=""
spazio=" "
if var in diz_successive:
    for i in range(1,lunghezza_frase+1):
        var1=random.choice(diz_successive[var])
        var=var1
        stringa=stringa+var1+spazio
else:
    print("non è nel dizionario")
    
print(stringa)
# Out:
# la frase è:
# che t'ha preso posto e seguitando di scena la figliastra lei finisca la figliastra con quelle bestie senza badare all'interruzione nuova famigliuola di due mesi glie l'ho dichiarato fin da

# %% [markdown]
# ## Classe

# %%
import random

class TextGenerator():
    def __init__(self, file, punteggiatura):
        self.file = file
        self.punteggiatura = punteggiatura
        self.parole = []
        self.successivi = {}

    def fileToListaParole(self):
        with open(self.file, "r") as file:
            righe = file.readlines()

        righe_senza_return = [riga[:-1] for riga in righe if len(riga) > 1]
        libro = " ".join(righe_senza_return).lower()

        for carattere in self.punteggiatura:
            libro = libro.replace(carattere, " ")
        self.parole = [parola for parola in libro.split() if len(parola) > 0]

    def creaDizionarioSuccessive(self):
        for i in range(len(self.parole) - 1):
            parola_corrente = self.parole[i]
            parola_successiva = self.parole[i + 1]

            if parola_corrente in self.successivi:
                self.successivi[parola_corrente].append(parola_successiva)
            else:
                self.successivi[parola_corrente] = [parola_successiva]

    def generaFraseCasuale(self, lunghezza_frase, parola_iniziale):
        
        var = parola_iniziale
        stringa = ""
        spazio = " "

        if var in self.successivi:
            for _ in range(lunghezza_frase):
                var1 = random.choice(self.successivi[var])
                var = var1
                stringa = stringa + var1 + spazio
        else:
            print(f"'{var}' non è nel dizionario delle parole successive.")

        return stringa

# %%
file_nome = "sei_personaggi_in_cerca_dautore_Luigi_Pirandello.txt"
punteggiatura = [",", ".", ":", ";", "(", ")", "?", "!", "-", "»"]
generator = TextGenerator(file_nome, punteggiatura)
generator.fileToListaParole()
generator.creaDizionarioSuccessive()

lunghezza_frase_desiderata = int(input("lunghezza frase: "))
parola_iniziale = input("parola iniziale: ") 
frase_generata = generator.generaFraseCasuale(lunghezza_frase_desiderata, parola_iniziale)
print(f"La frase generata è: {parola_iniziale} {frase_generata}")
